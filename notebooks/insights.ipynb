# %%
import pandas as pd

df = pd.read_csv("../data/2021/accident.csv",encoding="cp1252",low_memory=False)
print(df["WEATHER"].value_counts())
weather_df = pd.read_csv("../data/2021/weather.csv",encoding="cp1252",low_memory=False)
print(weather_df.head())
print(weather_df["WEATHERNAME"].value_counts())
# Out:
# WEATHER
# 1     28977
# 10     5413
# 2      2616
# 98     1604
# 5       476
# 4       305
# 99      175
# 6        68
# 8        46
# 3        33
# 12       29
# 11       28
# 7        15
# Name: count, dtype: int64
#    STATE STATENAME  ST_CASE  WEATHER WEATHERNAME
# 0      1   Alabama    10001        2        Rain
# 1      1   Alabama    10002        2        Rain
# 2      1   Alabama    10003        2        Rain
# 3      1   Alabama    10004        1       Clear
# 4      1   Alabama    10005       10      Cloudy
